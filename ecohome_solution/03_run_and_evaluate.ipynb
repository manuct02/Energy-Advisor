# %% [markdown]
# # EcoHome Energy Advisor - Agent Run & Evaluation
#
# In this notebook, you'll run the Energy Advisor agent with various real-world scenarios and see how it helps customers optimize their energy usage.
#
# ## Learning Objectives
# - Create the agent's instructions
# - Run the Energy Advisor with different types of questions
# - Evaluate response quality and accuracy
# - Measure tool usage effectiveness
# - Identify areas for improvement
# - Implement evaluation metrics
#
# ## Evaluation Criteria
# - **Accuracy**: Correct information and calculations
# - **Relevance**: Responses address the user's question
# - **Completeness**: Comprehensive answers with actionable advice
# - **Tool Usage**: Appropriate use of available tools
# - **Reasoning**: Clear explanation of recommendations

# %% [markdown]
# ## 1. Import and Initialize

# %%
from datetime import datetime
from agent import Agent

# %%
ECOHOME_SYSTEM_PROMPT = """
You are EcoHome Energy Advisor, an AI assistant that helps users optimize home energy usage.

Your objectives:
- Minimize electricity cost
- Maximize solar energy usage when available
- Maintain user comfort and practical constraints

You have access to tools that provide:
- Weather forecasts (including solar irradiance)
- Time-of-use electricity pricing
- Historical energy usage and solar generation
- Energy-saving tips and best practices
- Energy savings calculations

Guidelines:
- Use tools whenever data is required to answer accurately.
- For questions about timing, cost, or solar optimization, consider BOTH weather and electricity prices.
- For questions based on past behavior, use historical energy usage data.
- Always provide a clear, actionable recommendation (what to do and when).
- Explain briefly WHY the recommendation is optimal.
- Include cost or energy impact estimates when possible.

If required information is missing, make reasonable assumptions and state them clearly.
If a tool fails, proceed with best-effort reasoning.

Response style:
- Clear and concise
- Practical and realistic
- Structured when helpful (steps or bullet points)
"""

# %%
ecohome_agent = Agent(
    instructions=ECOHOME_SYSTEM_PROMPT,
)

# %%
response = ecohome_agent.invoke(
    question="When should I charge my electric car tomorrow to minimize cost and maximize solar power?",
    context="Location: Madrid, Spain"
)

# %%
print(response["messages"][-1].content)
# Out:
# To minimize costs and maximize solar power when charging your electric car tomorrow (October 7, 2023), follow these recommendations:
#
# ### Optimal Charging Time
# - **Charge your electric car between 12:00 PM and 3:00 PM.**
#
# ### Reasons for This Recommendation
# 1. **Solar Power Availability**:
#    - Solar irradiance is expected to peak around **12:00 PM to 2:00 PM**, with the highest solar generation at **12:00 PM** (543 W/m²) and **1:00 PM** (639.8 W/m²). This means more solar energy will be available to offset your charging needs during this time.
#
# 2. **Electricity Pricing**:
#    - The electricity rates during this time are **$0.18 per kWh** (from 12:00 PM to 3:00 PM), which is higher than the off-peak rate of **$0.09 per kWh** (from 12:00 AM to 6:00 AM and after 11:00 PM). However, charging during peak solar generation will allow you to utilize solar energy, reducing your reliance on grid electricity.
#
# ### Summary of Electricity Rates
# - **12:00 PM - 3:00 PM**: $0.18 per kWh (peak)
# - **Off-Peak**: $0.09 per kWh (12:00 AM - 6:00 AM, 11:00 PM - 12:00 AM)
#
# ### Action Steps
# 1. **Set your car to charge starting at 12:00 PM**.
# 2. **Monitor solar generation** if possible, and adjust the charging time slightly earlier or later based on real-time solar availability.
#
# By following this plan, you will maximize the use of solar energy while keeping your charging costs relatively low.

# %%
print("TOOLS:")
for msg in response["messages"]:
    obj = msg.model_dump()
    if obj.get("tool_call_id"):
        print("-", msg.name)
# Out:
# TOOLS:
# - get_weather_forecast
# - get_electricity_prices

# %% [markdown]
# ## 2. Define Test Cases

# %%
# TODO: Define comprehensive test cases for the Energy Advisor
# Create 10 test cases covering different scenarios:
# - EV charging optimization
# - Thermostat settings
# - Appliance scheduling
# - Solar power maximization
# - Cost savings calculations

# %%
test_cases = [
    {
        "id": "ev_charging_1",
        "question": "When should I charge my electric car tomorrow to minimize cost and maximize solar power?",
        "expected_tools": ["get_weather_forecast", "get_electricity_prices"],
        "expected_response": "time recommendation, cost analysis and solar consideration",
    },
    {
        "id": "hvac_peak_prices",
        "question": "What temperature should I set my thermostat tomorrow evening if electricity prices are high?",
        "expected_tools": ["get_electricity_prices"],
        "expected_response": "thermostat recommendation considering peak prices",
    },
    {
        "id": "dishwasher_off_peak",
        "question": "How much can I save by running my dishwasher during off-peak hours?",
        "expected_tools": ["get_electricity_prices", "calculate_energy_savings"],
        "expected_response": "cost savings estimate",
    },
    {
        "id": "solar_usage_today",
        "question": "What's the best time today to use appliances to maximize solar energy?",
        "expected_tools": ["get_weather_forecast"],
        "expected_response": "solar-based timing recommendation",
    },
    {
        "id": "weekly_usage_tips",
        "question": "Suggest three ways I can reduce energy use based on my recent usage.",
        "expected_tools": ["get_recent_energy_summary", "search_energy_tips"],
        "expected_response": "three personalized recommendations",
    },
    {
        "id": "ev_cost_analysis",
        "question": "Is it cheaper to charge my EV at night or in the afternoon?",
        "expected_tools": ["get_electricity_prices"],
        "expected_response": "comparison of charging costs",
    },
    {
        "id": "solar_generation_history",
        "question": "How much solar energy did I generate last week?",
        "expected_tools": ["query_solar_generation"],
        "expected_response": "summary of solar generation",
    },
    {
        "id": "energy_summary_24h",
        "question": "Give me a summary of my energy usage in the last 24 hours.",
        "expected_tools": ["get_recent_energy_summary"],
        "expected_response": "usage and cost summary",
    },
    {
        "id": "appliance_scheduling",
        "question": "When should I run my washing machine to reduce costs?",
        "expected_tools": ["get_electricity_prices"],
        "expected_response": "optimal scheduling recommendation",
    },
    {
        "id": "hvac_solar_preheat",
        "question": "Should I pre-cool my house tomorrow using solar power?",
        "expected_tools": ["get_weather_forecast"],
        "expected_response": "pre-cooling recommendation based on solar forecast",
    },
]

if len(test_cases) < 10:
    raise ValueError("You MUST have at least 10 test cases")

# %% [markdown]
# ## 3. Run Agent Tests

# %%
CONTEXT = "Location: Madrid, Spain"

# %%
# Run the agent tests
# For each test case, call the agent and collect the response
# Store results for evaluation

print("=== Running Agent Tests ===")
test_results = []

for i, test_case in enumerate(test_cases):
    print(f"\nTest {i+1}: {test_case['id']}")
    print(f"Question: {test_case['question']}")
    print("-" * 50)
    
    try:
        # Call the agent
        response = ecohome_agent.invoke(
            question=test_case['question'],
            context=CONTEXT
        )
        
        # Store the result
        result = {
            'test_id': test_case['id'],
            'question': test_case['question'],
            'response': response,
            'expected_tools': test_case['expected_tools'],
            'expected_response': test_case['expected_response'],
            'timestamp': datetime.now().isoformat()
        }
        test_results.append(result)
                
    except Exception as e:
        print(f"Error: {e}")
        result = {
            'test_id': test_case['id'],
            'question': test_case['question'],
            'response': f"Error: {str(e)}",
            'expected_tools': test_case['expected_tools'],
            'expected_response': test_case['expected_response'],
            'timestamp': datetime.now().isoformat(),
            'error': str(e)
        }
        test_results.append(result)

print(f"\nCompleted {len(test_results)} tests")
# Out:
# === Running Agent Tests ===
#
# Test 1: ev_charging_1
# Question: When should I charge my electric car tomorrow to minimize cost and maximize solar power?
# --------------------------------------------------
#
# Test 2: hvac_peak_prices
# Question: What temperature should I set my thermostat tomorrow evening if electricity prices are high?
# --------------------------------------------------
#
# Test 3: dishwasher_off_peak
# Question: How much can I save by running my dishwasher during off-peak hours?
# --------------------------------------------------
#
# Test 4: solar_usage_today
# Question: What's the best time today to use appliances to maximize solar energy?
# --------------------------------------------------
#
# Test 5: weekly_usage_tips
# Question: Suggest three ways I can reduce energy use based on my recent usage.
# --------------------------------------------------
#
# Test 6: ev_cost_analysis
# Question: Is it cheaper to charge my EV at night or in the afternoon?
# --------------------------------------------------
#
# Test 7: solar_generation_history
# Question: How much solar energy did I generate last week?
# --------------------------------------------------
#
# Test 8: energy_summary_24h
# Question: Give me a summary of my energy usage in the last 24 hours.
# --------------------------------------------------
#
# Test 9: appliance_scheduling
# Question: When should I run my washing machine to reduce costs?
# --------------------------------------------------
#
# Test 10: hvac_solar_preheat
# Question: Should I pre-cool my house tomorrow using solar power?
# --------------------------------------------------
#
# Completed 10 tests

# %%
test_results
# Out:
# [{'test_id': 'ev_charging_1',
#   'question': 'When should I charge my electric car tomorrow to minimize cost and maximize solar power?',
#   'response': {'messages': [SystemMessage(content='Location: Madrid, Spain', additional_kwargs={}, response_metadata={}, id='1663b7c0-31b4-4279-9732-79824086809a'),
#     HumanMessage(content='When should I charge my electric car tomorrow to minimize cost and maximize solar power?', additional_kwargs={}, response_metadata={}, id='e96efc0d-166b-4d74-8d04-b74fdeb7c103'),
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 60, 'prompt_tokens': 1081, 'total_tokens': 1141, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-CxwygwES74BXSvsDm2KLF8SP6MiVR', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--019bbd19-1891-7522-b87f-4c29b0b9e8ac-0', tool_calls=[{'name': 'get_weather_forecast', 'args': {'location': 'Madrid, Spain', 'days': 1}, 'id': 'call_r9yC4hLD1YeRK7p7bNOR9GHl', 'type': 'tool_call'}, {'name': 'get_electricity_prices', 'args': {'date': '2023-10-07'}, 'id': 'call_OFCSq4lwnSGKt7qV5cTYsLHg', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1081, 'output_tokens': 60, 'total_tokens': 1141, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"location": "Madrid, Spain", "forecast_days": 1, "source": "mock_fallback", "current": {"temperature_c": 12.4, "condition": "partly_cloudy", "humidity": 48, "wind_speed": 41.3, "solar_irradiance": 318.6}, "hourly": [{"timestamp": "2026-01-14T15:00:00+00:00", "hour": 15, "temperature_c": 12.4, "condition": "partly_cloudy", "humidity": 48, "wind_speed": 41.3, "solar_irradiance": 318.6}, {"timestamp": "2026-01-14T16:00:00+00:00", "hour": 16, "temperature_c": 11.5, "condition": "partly_cloudy", "humidity": 62, "wind_speed": 60.2, "solar_irradiance": 269.1}, {"timestamp": "2026-01-14T17:00:00+00:00", "hour": 17, "temperature_c": 10.1, "condition": "partly_cloudy", "humidity": 83, "wind_speed": 65.5, "solar_irradiance": 188.2}, {"timestamp": "2026-01-14T18:00:00+00:00", "hour": 18, "temperature_c": 9.5, "condition": "partly_cloudy", "humidity": 70, "wind_speed": 66.6, "solar_irradiance": 96.2}, {"timestamp": "2026-01-14T19:00:00+00:00", "hour": 19, "temperature_c": 7.4, "condition": "cloudy", "humidity": 51, "wind_speed": 54.5, "solar_irradiance": 48.7}, {"timestamp": "2026-01-14T20:00:00+00:00", "hour": 20, "temperature_c": 7.2, "condition": "partly_cloudy", "humidity": 46, "wind_speed": 67.7, "solar_irradiance": 0.0}, {"timestamp": "2026-01-14T21:00:00+00:00", "hour": 21, "temperature_c": 5.3, "condition": "rainy", "humidity": 29, "wind_speed": 54.8, "solar_irradiance": 0.0}, {"timestamp": "2026-01-14T22:00:00+00:00", "hour": 22, "temperature_c": 4.8, "condition": "partly_cloudy", "humidity": 60, "wind_speed": 59.8, "solar_irradiance": 0.0}, {"timestamp": "2026-01-14T23:00:00+00:00", "hour": 23, "temperature_c": 5.1, "condition": "partly_cloudy", "humidity": 59, "wind_speed": 63.1, "solar_irradiance": 0.0}, {"timestamp": "2026-01-15T00:00:00+00:00", "hour": 0, "temperature_c": 5.0, "condition": "cloudy", "humidity": 54, "wind_speed": 48.4, "solar_irradiance": 0.0}, {"timestamp": "2026-01-15T01:00:00+00:00", "hour": 1, "temperature_c": 5.2, "condition": "partly_cloudy", "humidity": 74, "wind_speed": 39.3, "solar_irradiance": 0.0}, {"timestamp": "2026-01-15T02:00:00+00:00", "hour": 2, "temperature_c": 4.8, "condition": "partly_cloudy", "humidity": 53, "wind_speed": 62.3, "solar_irradiance": 0.0}, {"timestamp": "2026-01-15T03:00:00+00:00", "hour": 3, "temperature_c": 6.2, "condition": "partly_cloudy", "humidity": 42, "wind_speed": 51.1, "solar_irradiance": 0.0}, {"timestamp": "2026-01-15T04:00:00+00:00", "hour": 4, "temperature_c": 6.2, "condition": "partly_cloudy", "humidity": 77, "wind_speed": 39.5, "solar_irradiance": 0.0}, {"timestamp": "2026-01-15T05:00:00+00:00", "hour": 5, "temperature_c": 8.0, "condition": "partly_cloudy", "humidity": 36, "wind_speed": 40.1, "solar_irradiance": 0.0}, {"timestamp": "2026-01-15T06:00:00+00:00", "hour": 6, "temperature_c": 8.8, "condition": "cloudy", "humidity": 53, "wind_speed": 39.2, "solar_irradiance": 0.0}, {"timestamp": "2026-01-15T07:00:00+00:00", "hour": 7, "temperature_c": 10.5, "condition": "partly_cloudy", "humidity": 46, "wind_speed": 34.5, "solar_irradiance": 55.0}, {"timestamp": "2026-01-15T08:00:00+00:00", "hour": 8, "temperature_c": 11.1, "condition": "sunny", "humidity": 64, "wind_speed": 65.6, "solar_irradiance": 87.5}, {"timestamp": "2026-01-15T09:00:00+00:00", "hour": 9, "temperature_c": 12.1, "condition": "partly_cloudy", "humidity": 55, "wind_speed": 43.5, "solar_irradiance": 182.8}, {"timestamp": "2026-01-15T10:00:00+00:00", "hour": 10, "temperature_c": 13.4, "condition": "partly_cloudy", "humidity": 64, "wind_speed": 59.5, "solar_irradiance": 277.4}, {"timestamp": "2026-01-15T11:00:00+00:00", "hour": 11, "temperature_c": 13.2, "condition": "partly_cloudy", "humidity": 53, "wind_speed": 50.4, "solar_irradiance": 432.4}, {"timestamp": "2026-01-15T12:00:00+00:00", "hour": 12, "temperature_c": 13.0, "condition": "partly_cloudy", "humidity": 21, "wind_speed": 70.6, "solar_irradiance": 543.0}, {"timestamp": "2026-01-15T13:00:00+00:00", "hour": 13, "temp ...
#     ToolMessage(content='{"date": "2023-10-07", "pricing_type": "time_of_use", "currency": "USD", "unit": "per_kwh", "hourly_rates": [{"hour": 0, "rate": 0.09, "period": "off_peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.09, "period": "off_peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.09, "period": "off_peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.09, "period": "off_peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.09, "period": "off_peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.09, "period": "off_peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.156, "period": "peak", "demand_charge": 0.05}, {"hour": 7, "rate": 0.156, "period": "peak", "demand_charge": 0.05}, {"hour": 8, "rate": 0.156, "period": "peak", "demand_charge": 0.05}, {"hour": 9, "rate": 0.156, "period": "peak", "demand_charge": 0.05}, {"hour": 10, "rate": 0.156, "period": "peak", "demand_charge": 0.05}, {"hour": 11, "rate": 0.156, "period": "peak", "demand_charge": 0.05}, {"hour": 12, "rate": 0.18, "period": "peak", "demand_charge": 0.05}, {"hour": 13, "rate": 0.18, "period": "peak", "demand_charge": 0.05}, {"hour": 14, "rate": 0.18, "period": "peak", "demand_charge": 0.05}, {"hour": 15, "rate": 0.18, "period": "peak", "demand_charge": 0.05}, {"hour": 16, "rate": 0.18, "period": "peak", "demand_charge": 0.05}, {"hour": 17, "rate": 0.18, "period": "peak", "demand_charge": 0.05}, {"hour": 18, "rate": 0.216, "period": "peak", "demand_charge": 0.05}, {"hour": 19, "rate": 0.216, "period": "peak", "demand_charge": 0.05}, {"hour": 20, "rate": 0.216, "period": "peak", "demand_charge": 0.05}, {"hour": 21, "rate": 0.216, "period": "peak", "demand_charge": 0.05}, {"hour": 22, "rate": 0.216, "period": "peak", "demand_charge": 0.05}, {"hour": 23, "rate": 0.09, "period": "off_peak", "demand_charge": 0.0}]}', name='get_electricity_prices', id='d5297978-24fc-4e40-bccf-35c26890e723', tool_call_id='call_OFCSq4lwnSGKt7qV5cTYsLHg'),
#     AIMessage(content='To minimize costs and maximize solar power for charging your electric car tomorrow (October 7, 2023), here’s the optimal plan:\n\n### Key Insights:\n1. **Solar Power Availability**:\n   - Solar irradiance is expected to peak between **12 PM and 2 PM** with the highest value at **1 PM** (approximately 639.8 W/m²).\n   \n2. **Electricity Pricing**:\n   - **Off-Peak Rates**: \n     - 12 AM - 6 AM: $0.09/kWh\n     - 11 PM - 12 AM: $0.09/kWh\n   - **Peak Rates**:\n     - 6 AM - 8 AM: $0.156/kWh\n     - 8 AM - 12 PM: $0.156/kWh\n     - 12 PM - 6 PM: $0.18/kWh\n     - 6 PM - 9 PM: $0.216/kWh\n\n### Recommendation:\n- **Charge your electric car between 12 PM and 2 PM**:\n  - **Why?** This time frame allows you to take advantage of the peak solar generation, which will help reduce your reliance on grid electricity and lower your overall charging costs.\n  - **Cost Impact**: Charging during this time will be at a rate of $0.18/kWh, which is higher than the off-peak rate but lower than the evening peak rates.\n\n### Additional Tips:\n- If you can charge your car during the **off-peak hours (12 AM - 6 AM)**, you will benefit from the lowest rate of $0.09/kWh, but this will not utilize solar power.\n- Consider setting your car to charge just before noon to ensure it is ready by the time solar generation peaks.\n\nBy following this plan, you can effectively balance cost savings with maximizing the use of solar energy.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 394, 'prompt_tokens': 3745, 'total_tokens': 4139, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 2944}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-Cxwyieuf4ofXpiv7Ir3fcE46Re0ah', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--019bbd19-238e-7271-b65e-98802d153fcf-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 3745, 'output_tokens': 394, 'total_tokens': 4139, 'input_token_details': {'audio': 0, 'cache_read': 2944}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['get_weather_forecast', 'get_electricity_prices'],
#   'expected_response': 'time recommendation, cost analysis and solar consideration',
#   'timestamp': '2026-01-14T16:21:46.853777'},
#  {'test_id': 'hvac_peak_prices',
#   'question': 'What temperature should I set my thermostat tomorrow evening if electricity prices are high?',
#   'response': {'messages': [SystemMessage(content='Location: Madrid, Spain', additional_kwargs={}, response_metadata={}, id='71a4e5e9-b542-4194-919b-4e5d44b78875'),
#     HumanMessage(content='What temperature should I set my thermostat tomorrow evening if electricity prices are high?', additional_kwargs={}, response_metadata={}, id='f98754d5-74aa-45ef-9e77-7368e133e77b'),
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 60, 'prompt_tokens': 1080, 'total_tokens': 1140, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-CxwypPL1ZUs4DUzCxm2zdSwremIXc', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--019bbd19-3e66-76c3-b0a4-e685ef94b0e3-0', tool_calls=[{'name': 'get_electricity_prices', 'args': {'date': '2023-10-07'}, 'id': 'call_SbnW3mIZzsuFiZYwZERxDp5a', 'type': 'tool_call'}, {'name': 'get_weather_forecast', 'args': {'location': 'Madrid, Spain', 'days': 1}, 'id': 'call_hKh6mewEVUgLu19pF6JShr0T', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1080, 'output_tokens': 60, 'total_tokens': 1140, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"date": "2023-10-07", "pricing_type": "time_of_use", "currency": "USD", "unit": "per_kwh", "hourly_rates": [{"hour": 0, "rate": 0.09, "period": "off_peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.09, "period": "off_peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.09, "period": "off_peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.09, "period": "off_peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.09, "period": "off_peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.09, "period": "off_peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.156, "period": "peak", "demand_charge": 0.05}, {"hour": 7, "rate": 0.156, "period": "peak", "demand_charge": 0.05}, {"hour": 8, "rate": 0.156, "period": "peak", "demand_charge": 0.05}, {"hour": 9, "rate": 0.156, "period": "peak", "demand_charge": 0.05}, {"hour": 10, "rate": 0.156, "period": "peak", "demand_charge": 0.05}, {"hour": 11, "rate": 0.156, "period": "peak", "demand_charge": 0.05}, {"hour": 12, "rate": 0.18, "period": "peak", "demand_charge": 0.05}, {"hour": 13, "rate": 0.18, "period": "peak", "demand_charge": 0.05}, {"hour": 14, "rate": 0.18, "period": "peak", "demand_charge": 0.05}, {"hour": 15, "rate": 0.18, "period": "peak", "demand_charge": 0.05}, {"hour": 16, "rate": 0.18, "period": "peak", "demand_charge": 0.05}, {"hour": 17, "rate": 0.18, "period": "peak", "demand_charge": 0.05}, {"hour": 18, "rate": 0.216, "period": "peak", "demand_charge": 0.05}, {"hour": 19, "rate": 0.216, "period": "peak", "demand_charge": 0.05}, {"hour": 20, "rate": 0.216, "period": "peak", "demand_charge": 0.05}, {"hour": 21, "rate": 0.216, "period": "peak", "demand_charge": 0.05}, {"hour": 22, "rate": 0.216, "period": "peak", "demand_charge": 0.05}, {"hour": 23, "rate": 0.09, "period": "off_peak", "demand_charge": 0.0}]}', name='get_electricity_prices', id='4d0bdc65-9657-4240-ab64-f7c4ebd1838b', tool_call_id='call_SbnW3mIZzsuFiZYwZERxDp5a'),
#     ToolMessage(content='{"location": "Madrid, Spain", "forecast_days": 1, "source": "mock_fallback", "current": {"temperature_c": 12.4, "condition": "partly_cloudy", "humidity": 48, "wind_speed": 41.3, "solar_irradiance": 318.6}, "hourly": [{"timestamp": "2026-01-14T15:00:00+00:00", "hour": 15, "temperature_c": 12.4, "condition": "partly_cloudy", "humidity": 48, "wind_speed": 41.3, "solar_irradiance": 318.6}, {"timestamp": "2026-01-14T16:00:00+00:00", "hour": 16, "temperature_c": 11.5, "condition": "partly_cloudy", "humidity": 62, "wind_speed": 60.2, "solar_irradiance": 269.1}, {"timestamp": "2026-01-14T17:00:00+00:00", "hour": 17, "temperature_c": 10.1, "condition": "partly_cloudy", "humidity": 83, "wind_speed": 65.5, "solar_irradiance": 188.2}, {"timestamp": "2026-01-14T18:00:00+00:00", "hour": 18, "temperature_c": 9.5, "condition": "partly_cloudy", "humidity": 70, "wind_speed": 66.6, "solar_irradiance": 96.2}, {"timestamp": "2026-01-14T19:00:00+00:00", "hour": 19, "temperature_c": 7.4, "condition": "cloudy", "humidity": 51, "wind_speed": 54.5, "solar_irradiance": 48.7}, {"timestamp": "2026-01-14T20:00:00+00:00", "hour": 20, "temperature_c": 7.2, "condition": "partly_cloudy", "humidity": 46, "wind_speed": 67.7, "solar_irradiance": 0.0}, {"timestamp": "2026-01-14T21:00:00+00:00", "hour": 21, "temperature_c": 5.3, "condition": "rainy", "humidity": 29, "wind_speed": 54.8, "solar_irradiance": 0.0}, {"timestamp": "2026-01-14T22:00:00+00:00", "hour": 22, "temperature_c": 4.8, "condition": "partly_cloudy", "humidity": 60, "wind_speed": 59.8, "solar_irradiance": 0.0}, {"timestamp": "2026-01-14T23:00:00+00:00", "hour": 23, "temperature_c": 5.1, "condition": "partly_cloudy", "humidity": 59, "wind_speed": 63.1, "solar_irradiance": 0.0}, {"timestamp": "2026-01-15T00:00:00+00:00", "hour": 0, "temperature_c": 5.0, "condition": "cloudy", "humidity": 54, "wind_speed": 48.4, "solar_irradiance": 0.0}, {"timestamp": "2026-01-15T01:00:00+00:00", "hour": 1, "temperature_c": 5.2, "condition": "partly_cloudy", "humidity": 74, "wind_speed": 39.3, "solar_irradiance": 0.0}, {"timestamp": "2026-01-15T02:00:00+00:00", "hour": 2, "temperature_c": 4.8, "condition": "partly_cloudy", "humidity": 53, "wind_speed": 62.3, "solar_irradiance": 0.0}, {"timestamp": "2026-01-15T03:00:00+00:00", "hour": 3, "temperature_c": 6.2, "condition": "partly_cloudy", "humidity": 42, "wind_speed": 51.1, "solar_irradiance": 0.0}, {"timestamp": "2026-01-15T04:00:00+00:00", "hour": 4, "temperature_c": 6.2, "condition": "partly_cloudy", "humidity": 77, "wind_speed": 39.5, "solar_irradiance": 0.0}, {"timestamp": "2026-01-15T05:00:00+00:00", "hour": 5, "temperature_c": 8.0, "condition": "partly_cloudy", "humidity": 36, "wind_speed": 40.1, "solar_irradiance": 0.0}, {"timestamp": "2026-01-15T06:00:00+00:00", "hour": 6, "temperature_c": 8.8, "condition": "cloudy", "humidity": 53, "wind_speed": 39.2, "solar_irradiance": 0.0}, {"timestamp": "2026-01-15T07:00:00+00:00", "hour": 7, "temperature_c": 10.5, "condition": "partly_cloudy", "humidity": 46, "wind_speed": 34.5, "solar_irradiance": 55.0}, {"timestamp": "2026-01-15T08:00:00+00:00", "hour": 8, "temperature_c": 11.1, "condition": "sunny", "humidity": 64, "wind_speed": 65.6, "solar_irradiance": 87.5}, {"timestamp": "2026-01-15T09:00:00+00:00", "hour": 9, "temperature_c": 12.1, "condition": "partly_cloudy", "humidity": 55, "wind_speed": 43.5, "solar_irradiance": 182.8}, {"timestamp": "2026-01-15T10:00:00+00:00", "hour": 10, "temperature_c": 13.4, "condition": "partly_cloudy", "humidity": 64, "wind_speed": 59.5, "solar_irradiance": 277.4}, {"timestamp": "2026-01-15T11:00:00+00:00", "hour": 11, "temperature_c": 13.2, "condition": "partly_cloudy", "humidity": 53, "wind_speed": 50.4, "solar_irradiance": 432.4}, {"timestamp": "2026-01-15T12:00:00+00:00", "hour": 12, "temperature_c": 13.0, "condition": "partly_cloudy", "humidity": 21, "wind_speed": 70.6, "solar_irradiance": 543.0}, {"timestamp": "2026-01-15T13:00:00+00:00", "hour": 13, "temp ...
#     AIMessage(content='### Recommendation for Thermostat Setting Tomorrow Evening\n\n**Evening Electricity Prices:**\n- From 18:00 to 22:00, the electricity prices are high, ranging from **$0.216 per kWh**.\n\n**Weather Forecast:**\n- **Evening Temperatures:**\n  - 18:00: 9.5°C\n  - 19:00: 7.4°C\n  - 20:00: 7.2°C\n  - 21:00: 5.3°C\n  - 22:00: 4.8°C\n\n### Suggested Thermostat Setting:\n- **Set your thermostat to around 18°C (64°F)** during the evening hours.\n\n### Why This Setting is Optimal:\n1. **Cost Efficiency:** Setting the thermostat to 18°C will help reduce heating costs during peak pricing hours while still maintaining comfort.\n2. **Comfort Level:** This temperature is generally considered comfortable for most people, especially in cooler weather.\n3. **Energy Savings:** By avoiding excessive heating during high-cost periods, you can save on your electricity bill.\n\n### Action Steps:\n- Adjust your thermostat to 18°C before the evening peak pricing starts (around 17:30).\n- Monitor the temperature and adjust if necessary for personal comfort.\n\nThis approach balances cost savings with maintaining a comfortable living environment.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 277, 'prompt_tokens': 3743, 'total_tokens': 4020, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-Cxwyrv13dEtU0cbPjTqY1IETJb9uE', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--019bbd19-45a4-7603-b45f-d73526b8b2c1-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 3743, 'output_tokens': 277, 'total_tokens': 4020, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['get_electricity_prices'],
#   'expected_response': 'thermostat recommendation considering peak prices',
#   'timestamp': '2026-01-14T16:21:54.463566'},
#  {'test_id': 'dishwasher_off_peak',
#   'question': 'How much can I save by running my dishwasher during off-peak hours?',
#   'response': {'messages': [SystemMessage(content='Location: Madrid, Spain', additional_kwargs={}, response_metadata={}, id='981e5b39-d6e1-41c5-bd39-108f3d9ab0b5'),
#     HumanMessage(content='How much can I save by running my dishwasher during off-peak hours?', additional_kwargs={}, response_metadata={}, id='a35ecdfc-41a1-4f45-91c6-48c01a81d516'),
#     AIMessage(content="To calculate your potential savings by running your dishwasher during off-peak hours, I need to know:\n\n1. The current energy usage of your dishwasher (in kWh).\n2. The electricity prices for both peak and off-peak hours.\n\nI'll first retrieve the current electricity prices for today in Madrid. Then, if you can provide the energy usage of your dishwasher, I can calculate the savings. If you don't have that information, I can make a reasonable assumption based on average usage. Would you like me to proceed with that?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 107, 'prompt_tokens': 1080, 'total_tokens': 1187, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-CxwywMDUP1v6lGvnrfbUe7mAuptvx', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--019bbd19-5c21-73f1-9880-fb3bc723fa68-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1080, 'output_tokens': 107, 'total_tokens': 1187, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['get_electricity_prices', 'calculate_energy_savings'],
#   'expected_response': 'cost savings estimate',
#   'timestamp': '2026-01-14T16:21:56.919920'},
#  {'test_id': 'solar_usage_today',
#   'question': "What's the best time today to use appliances to maximize solar energy?",
#   'response': {'messages': [SystemMessage(content='Location: Madrid, Spain', additional_kwargs={}, response_metadata={}, id='dc67995d-ca05-4eb0-bd3e-975413ee3903'),
#     HumanMessage(content="What's the best time today to use appliances to maximize solar energy?", additional_kwargs={}, response_metadata={}, id='0f8ea388-29ae-4af9-8679-89617e8068b9'),
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 53, 'prompt_tokens': 1078, 'total_tokens': 1131, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-CxwyzkZzp2CNv5aox9RSfCaC4dGUw', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--019bbd19-65b9-7ca1-810f-1b3f89d777f6-0', tool_calls=[{'name': 'get_weather_forecast', 'args': {'location': 'Madrid, Spain', 'days': 1}, 'id': 'call_8tIF85lzw5brDBcQSzc4KOGw', 'type': 'tool_call'}, {'name': 'get_electricity_prices', 'args': {}, 'id': 'call_qy0GOI4Oid7c6lSSCYmqzNP5', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1078, 'output_tokens': 53, 'total_tokens': 1131, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"location": "Madrid, Spain", "forecast_days": 1, "source": "mock_fallback", "current": {"temperature_c": 12.4, "condition": "partly_cloudy", "humidity": 48, "wind_speed": 41.3, "solar_irradiance": 318.6}, "hourly": [{"timestamp": "2026-01-14T15:00:00+00:00", "hour": 15, "temperature_c": 12.4, "condition": "partly_cloudy", "humidity": 48, "wind_speed": 41.3, "solar_irradiance": 318.6}, {"timestamp": "2026-01-14T16:00:00+00:00", "hour": 16, "temperature_c": 11.5, "condition": "partly_cloudy", "humidity": 62, "wind_speed": 60.2, "solar_irradiance": 269.1}, {"timestamp": "2026-01-14T17:00:00+00:00", "hour": 17, "temperature_c": 10.1, "condition": "partly_cloudy", "humidity": 83, "wind_speed": 65.5, "solar_irradiance": 188.2}, {"timestamp": "2026-01-14T18:00:00+00:00", "hour": 18, "temperature_c": 9.5, "condition": "partly_cloudy", "humidity": 70, "wind_speed": 66.6, "solar_irradiance": 96.2}, {"timestamp": "2026-01-14T19:00:00+00:00", "hour": 19, "temperature_c": 7.4, "condition": "cloudy", "humidity": 51, "wind_speed": 54.5, "solar_irradiance": 48.7}, {"timestamp": "2026-01-14T20:00:00+00:00", "hour": 20, "temperature_c": 7.2, "condition": "partly_cloudy", "humidity": 46, "wind_speed": 67.7, "solar_irradiance": 0.0}, {"timestamp": "2026-01-14T21:00:00+00:00", "hour": 21, "temperature_c": 5.3, "condition": "rainy", "humidity": 29, "wind_speed": 54.8, "solar_irradiance": 0.0}, {"timestamp": "2026-01-14T22:00:00+00:00", "hour": 22, "temperature_c": 4.8, "condition": "partly_cloudy", "humidity": 60, "wind_speed": 59.8, "solar_irradiance": 0.0}, {"timestamp": "2026-01-14T23:00:00+00:00", "hour": 23, "temperature_c": 5.1, "condition": "partly_cloudy", "humidity": 59, "wind_speed": 63.1, "solar_irradiance": 0.0}, {"timestamp": "2026-01-15T00:00:00+00:00", "hour": 0, "temperature_c": 5.0, "condition": "cloudy", "humidity": 54, "wind_speed": 48.4, "solar_irradiance": 0.0}, {"timestamp": "2026-01-15T01:00:00+00:00", "hour": 1, "temperature_c": 5.2, "condition": "partly_cloudy", "humidity": 74, "wind_speed": 39.3, "solar_irradiance": 0.0}, {"timestamp": "2026-01-15T02:00:00+00:00", "hour": 2, "temperature_c": 4.8, "condition": "partly_cloudy", "humidity": 53, "wind_speed": 62.3, "solar_irradiance": 0.0}, {"timestamp": "2026-01-15T03:00:00+00:00", "hour": 3, "temperature_c": 6.2, "condition": "partly_cloudy", "humidity": 42, "wind_speed": 51.1, "solar_irradiance": 0.0}, {"timestamp": "2026-01-15T04:00:00+00:00", "hour": 4, "temperature_c": 6.2, "condition": "partly_cloudy", "humidity": 77, "wind_speed": 39.5, "solar_irradiance": 0.0}, {"timestamp": "2026-01-15T05:00:00+00:00", "hour": 5, "temperature_c": 8.0, "condition": "partly_cloudy", "humidity": 36, "wind_speed": 40.1, "solar_irradiance": 0.0}, {"timestamp": "2026-01-15T06:00:00+00:00", "hour": 6, "temperature_c": 8.8, "condition": "cloudy", "humidity": 53, "wind_speed": 39.2, "solar_irradiance": 0.0}, {"timestamp": "2026-01-15T07:00:00+00:00", "hour": 7, "temperature_c": 10.5, "condition": "partly_cloudy", "humidity": 46, "wind_speed": 34.5, "solar_irradiance": 55.0}, {"timestamp": "2026-01-15T08:00:00+00:00", "hour": 8, "temperature_c": 11.1, "condition": "sunny", "humidity": 64, "wind_speed": 65.6, "solar_irradiance": 87.5}, {"timestamp": "2026-01-15T09:00:00+00:00", "hour": 9, "temperature_c": 12.1, "condition": "partly_cloudy", "humidity": 55, "wind_speed": 43.5, "solar_irradiance": 182.8}, {"timestamp": "2026-01-15T10:00:00+00:00", "hour": 10, "temperature_c": 13.4, "condition": "partly_cloudy", "humidity": 64, "wind_speed": 59.5, "solar_irradiance": 277.4}, {"timestamp": "2026-01-15T11:00:00+00:00", "hour": 11, "temperature_c": 13.2, "condition": "partly_cloudy", "humidity": 53, "wind_speed": 50.4, "solar_irradiance": 432.4}, {"timestamp": "2026-01-15T12:00:00+00:00", "hour": 12, "temperature_c": 13.0, "condition": "partly_cloudy", "humidity": 21, "wind_speed": 70.6, "solar_irradiance": 543.0}, {"timestamp": "2026-01-15T13:00:00+00:00", "hour": 13, "temp ...
#     ToolMessage(content='{"date": "2026-01-14", "pricing_type": "time_of_use", "currency": "USD", "unit": "per_kwh", "hourly_rates": [{"hour": 0, "rate": 0.09, "period": "off_peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.09, "period": "off_peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.09, "period": "off_peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.09, "period": "off_peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.09, "period": "off_peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.09, "period": "off_peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.156, "period": "peak", "demand_charge": 0.05}, {"hour": 7, "rate": 0.156, "period": "peak", "demand_charge": 0.05}, {"hour": 8, "rate": 0.156, "period": "peak", "demand_charge": 0.05}, {"hour": 9, "rate": 0.156, "period": "peak", "demand_charge": 0.05}, {"hour": 10, "rate": 0.156, "period": "peak", "demand_charge": 0.05}, {"hour": 11, "rate": 0.156, "period": "peak", "demand_charge": 0.05}, {"hour": 12, "rate": 0.18, "period": "peak", "demand_charge": 0.05}, {"hour": 13, "rate": 0.18, "period": "peak", "demand_charge": 0.05}, {"hour": 14, "rate": 0.18, "period": "peak", "demand_charge": 0.05}, {"hour": 15, "rate": 0.18, "period": "peak", "demand_charge": 0.05}, {"hour": 16, "rate": 0.18, "period": "peak", "demand_charge": 0.05}, {"hour": 17, "rate": 0.18, "period": "peak", "demand_charge": 0.05}, {"hour": 18, "rate": 0.216, "period": "peak", "demand_charge": 0.05}, {"hour": 19, "rate": 0.216, "period": "peak", "demand_charge": 0.05}, {"hour": 20, "rate": 0.216, "period": "peak", "demand_charge": 0.05}, {"hour": 21, "rate": 0.216, "period": "peak", "demand_charge": 0.05}, {"hour": 22, "rate": 0.216, "period": "peak", "demand_charge": 0.05}, {"hour": 23, "rate": 0.09, "period": "off_peak", "demand_charge": 0.0}]}', name='get_electricity_prices', id='dc7cedb4-2674-4377-b795-85d30f06c0e9', tool_call_id='call_qy0GOI4Oid7c6lSSCYmqzNP5'),
#     AIMessage(content="To maximize solar energy usage today in Madrid, you should use your appliances during the hours when solar irradiance is highest. Here's the breakdown:\n\n### Optimal Time to Use Appliances:\n- **12:00 PM to 2:00 PM**: \n  - **12:00 PM**: Solar Irradiance: 543.0 W/m²\n  - **1:00 PM**: Solar Irradiance: 639.8 W/m² (Peak)\n  - **2:00 PM**: Solar Irradiance: 439.9 W/m²\n\n### Electricity Pricing:\n- **12:00 PM to 2:00 PM**: \n  - **12:00 PM**: $0.18 per kWh (Peak)\n  - **1:00 PM**: $0.18 per kWh (Peak)\n  - **2:00 PM**: $0.18 per kWh (Peak)\n\n### Recommendation:\n- **Use your appliances between 12:00 PM and 2:00 PM**. This is when solar energy production is at its highest, allowing you to utilize more solar power and reduce reliance on grid electricity.\n\n### Why This is Optimal:\n- By using appliances during peak solar hours, you can maximize the use of solar energy, which is typically less expensive than grid electricity. Although the electricity price is at its peak during these hours, the savings from using solar energy can offset the costs.\n\n### Additional Note:\n- If you have a battery storage system, consider charging it during these hours to use later when solar production decreases.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 325, 'prompt_tokens': 3735, 'total_tokens': 4060, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-Cxwz1SiZLe7vsm18Ro1gXec3j48Xe', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--019bbd19-6d24-7640-bec5-d84696f1b096-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 3735, 'output_tokens': 325, 'total_tokens': 4060, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['get_weather_forecast'],
#   'expected_response': 'solar-based timing recommendation',
#   'timestamp': '2026-01-14T16:22:05.586632'},
#  {'test_id': 'weekly_usage_tips',
#   'question': 'Suggest three ways I can reduce energy use based on my recent usage.',
#   'response': {'messages': [SystemMessage(content='Location: Madrid, Spain', additional_kwargs={}, response_metadata={}, id='24142a3e-013e-4400-8a78-c9424cabf9ec'),
#     HumanMessage(content='Suggest three ways I can reduce energy use based on my recent usage.', additional_kwargs={}, response_metadata={}, id='f6b4d85e-9d0d-436a-bb3c-6ebc9e4fecf0'),
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 1079, 'total_tokens': 1095, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-Cxwz893fSNwGZ5m6xKIu83EziNwhb', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--019bbd19-8795-7362-9844-b172e4f14d6a-0', tool_calls=[{'name': 'get_recent_energy_summary', 'args': {'hours': 24}, 'id': 'call_GL83wY0V3iQYuNcyNBlxxEUe', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1079, 'output_tokens': 16, 'total_tokens': 1095, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"time_period_hours": 24, "usage": {"total_consumption_kwh": 0, "total_cost_usd": 0, "device_breakdown": {}}, "generation": {"total_generation_kwh": 0, "average_weather": "unknown"}}', name='get_recent_energy_summary', id='a6f5a563-6142-4116-8c3f-09f9d219e289', tool_call_id='call_GL83wY0V3iQYuNcyNBlxxEUe'),
#     AIMessage(content="It appears that there is no recent energy usage data available for the last 24 hours. This could be due to a lack of recorded consumption or solar generation data.\n\nHowever, I can still provide general energy-saving tips that are effective in most households:\n\n1. **Optimize Heating and Cooling:**\n   - **Tip:** Set your thermostat to a lower temperature in winter and a higher temperature in summer. Consider using programmable thermostats to adjust temperatures based on your schedule.\n   - **Why:** This can significantly reduce energy consumption by minimizing the need for heating and cooling when you're not home.\n\n2. **Unplug Unused Devices:**\n   - **Tip:** Unplug electronics and appliances that are not in use, or use smart power strips that cut power to devices when they are not actively being used.\n   - **Why:** Many devices consume energy even when turned off (phantom load). Unplugging them can save energy and reduce your electricity bill.\n\n3. **Use Energy-Efficient Appliances:**\n   - **Tip:** If you have older appliances, consider replacing them with energy-efficient models that have the ENERGY STAR label.\n   - **Why:** Energy-efficient appliances use less electricity for the same performance, leading to lower energy bills over time.\n\nIf you can provide more specific details about your energy usage or any particular devices you want to focus on, I can offer more tailored recommendations.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 280, 'prompt_tokens': 1165, 'total_tokens': 1445, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-Cxwz9X9pzhSkPPFVjxJjBnaXc0LHp', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--019bbd19-8c57-7542-a5d4-77bce5d11da9-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1165, 'output_tokens': 280, 'total_tokens': 1445, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['get_recent_energy_summary', 'search_energy_tips'],
#   'expected_response': 'three personalized recommendations',
#   'timestamp': '2026-01-14T16:22:11.714663'},
#  {'test_id': 'ev_cost_analysis',
#   'question': 'Is it cheaper to charge my EV at night or in the afternoon?',
#   'response': {'messages': [SystemMessage(content='Location: Madrid, Spain', additional_kwargs={}, response_metadata={}, id='ec7d8d3d-2e7c-4c52-852f-56fd251d334c'),
#     HumanMessage(content='Is it cheaper to charge my EV at night or in the afternoon?', additional_kwargs={}, response_metadata={}, id='2e1570e7-52ae-4097-b38b-c63c11c7ddcf'),
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 48, 'prompt_tokens': 1079, 'total_tokens': 1127, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-CxwzErusV35IQpNsbYEnEaN4WxmAJ', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--019bbd19-9f84-74f0-bf8b-43ef737a8761-0', tool_calls=[{'name': 'get_electricity_prices', 'args': {}, 'id': 'call_D5kuizfF1qeHq9OHzlP31M23', 'type': 'tool_call'}, {'name': 'get_weather_forecast', 'args': {'location': 'Madrid, Spain'}, 'id': 'call_j7GYesXSrT71vZ4m5iijCNku', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1079, 'output_tokens': 48, 'total_tokens': 1127, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"date": "2026-01-14", "pricing_type": "time_of_use", "currency": "USD", "unit": "per_kwh", "hourly_rates": [{"hour": 0, "rate": 0.09, "period": "off_peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.09, "period": "off_peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.09, "period": "off_peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.09, "period": "off_peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.09, "period": "off_peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.09, "period": "off_peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.156, "period": "peak", "demand_charge": 0.05}, {"hour": 7, "rate": 0.156, "period": "peak", "demand_charge": 0.05}, {"hour": 8, "rate": 0.156, "period": "peak", "demand_charge": 0.05}, {"hour": 9, "rate": 0.156, "period": "peak", "demand_charge": 0.05}, {"hour": 10, "rate": 0.156, "period": "peak", "demand_charge": 0.05}, {"hour": 11, "rate": 0.156, "period": "peak", "demand_charge": 0.05}, {"hour": 12, "rate": 0.18, "period": "peak", "demand_charge": 0.05}, {"hour": 13, "rate": 0.18, "period": "peak", "demand_charge": 0.05}, {"hour": 14, "rate": 0.18, "period": "peak", "demand_charge": 0.05}, {"hour": 15, "rate": 0.18, "period": "peak", "demand_charge": 0.05}, {"hour": 16, "rate": 0.18, "period": "peak", "demand_charge": 0.05}, {"hour": 17, "rate": 0.18, "period": "peak", "demand_charge": 0.05}, {"hour": 18, "rate": 0.216, "period": "peak", "demand_charge": 0.05}, {"hour": 19, "rate": 0.216, "period": "peak", "demand_charge": 0.05}, {"hour": 20, "rate": 0.216, "period": "peak", "demand_charge": 0.05}, {"hour": 21, "rate": 0.216, "period": "peak", "demand_charge": 0.05}, {"hour": 22, "rate": 0.216, "period": "peak", "demand_charge": 0.05}, {"hour": 23, "rate": 0.09, "period": "off_peak", "demand_charge": 0.0}]}', name='get_electricity_prices', id='95383c03-f177-4163-9547-d21511b5facd', tool_call_id='call_D5kuizfF1qeHq9OHzlP31M23'),
#     ToolMessage(content='{"location": "Madrid, Spain", "forecast_days": 3, "source": "mock_fallback", "current": {"temperature_c": 12.4, "condition": "partly_cloudy", "humidity": 48, "wind_speed": 41.3, "solar_irradiance": 318.6}, "hourly": [{"timestamp": "2026-01-14T15:00:00+00:00", "hour": 15, "temperature_c": 12.4, "condition": "partly_cloudy", "humidity": 48, "wind_speed": 41.3, "solar_irradiance": 318.6}, {"timestamp": "2026-01-14T16:00:00+00:00", "hour": 16, "temperature_c": 11.5, "condition": "partly_cloudy", "humidity": 62, "wind_speed": 60.2, "solar_irradiance": 269.1}, {"timestamp": "2026-01-14T17:00:00+00:00", "hour": 17, "temperature_c": 10.1, "condition": "partly_cloudy", "humidity": 83, "wind_speed": 65.5, "solar_irradiance": 188.2}, {"timestamp": "2026-01-14T18:00:00+00:00", "hour": 18, "temperature_c": 9.5, "condition": "partly_cloudy", "humidity": 70, "wind_speed": 66.6, "solar_irradiance": 96.2}, {"timestamp": "2026-01-14T19:00:00+00:00", "hour": 19, "temperature_c": 7.4, "condition": "cloudy", "humidity": 51, "wind_speed": 54.5, "solar_irradiance": 48.7}, {"timestamp": "2026-01-14T20:00:00+00:00", "hour": 20, "temperature_c": 7.2, "condition": "partly_cloudy", "humidity": 46, "wind_speed": 67.7, "solar_irradiance": 0.0}, {"timestamp": "2026-01-14T21:00:00+00:00", "hour": 21, "temperature_c": 5.3, "condition": "rainy", "humidity": 29, "wind_speed": 54.8, "solar_irradiance": 0.0}, {"timestamp": "2026-01-14T22:00:00+00:00", "hour": 22, "temperature_c": 4.8, "condition": "partly_cloudy", "humidity": 60, "wind_speed": 59.8, "solar_irradiance": 0.0}, {"timestamp": "2026-01-14T23:00:00+00:00", "hour": 23, "temperature_c": 5.1, "condition": "partly_cloudy", "humidity": 59, "wind_speed": 63.1, "solar_irradiance": 0.0}, {"timestamp": "2026-01-15T00:00:00+00:00", "hour": 0, "temperature_c": 5.0, "condition": "cloudy", "humidity": 54, "wind_speed": 48.4, "solar_irradiance": 0.0}, {"timestamp": "2026-01-15T01:00:00+00:00", "hour": 1, "temperature_c": 5.2, "condition": "partly_cloudy", "humidity": 74, "wind_speed": 39.3, "solar_irradiance": 0.0}, {"timestamp": "2026-01-15T02:00:00+00:00", "hour": 2, "temperature_c": 4.8, "condition": "partly_cloudy", "humidity": 53, "wind_speed": 62.3, "solar_irradiance": 0.0}, {"timestamp": "2026-01-15T03:00:00+00:00", "hour": 3, "temperature_c": 6.2, "condition": "partly_cloudy", "humidity": 42, "wind_speed": 51.1, "solar_irradiance": 0.0}, {"timestamp": "2026-01-15T04:00:00+00:00", "hour": 4, "temperature_c": 6.2, "condition": "partly_cloudy", "humidity": 77, "wind_speed": 39.5, "solar_irradiance": 0.0}, {"timestamp": "2026-01-15T05:00:00+00:00", "hour": 5, "temperature_c": 8.0, "condition": "partly_cloudy", "humidity": 36, "wind_speed": 40.1, "solar_irradiance": 0.0}, {"timestamp": "2026-01-15T06:00:00+00:00", "hour": 6, "temperature_c": 8.8, "condition": "cloudy", "humidity": 53, "wind_speed": 39.2, "solar_irradiance": 0.0}, {"timestamp": "2026-01-15T07:00:00+00:00", "hour": 7, "temperature_c": 10.5, "condition": "partly_cloudy", "humidity": 46, "wind_speed": 34.5, "solar_irradiance": 55.0}, {"timestamp": "2026-01-15T08:00:00+00:00", "hour": 8, "temperature_c": 11.1, "condition": "sunny", "humidity": 64, "wind_speed": 65.6, "solar_irradiance": 87.5}, {"timestamp": "2026-01-15T09:00:00+00:00", "hour": 9, "temperature_c": 12.1, "condition": "partly_cloudy", "humidity": 55, "wind_speed": 43.5, "solar_irradiance": 182.8}, {"timestamp": "2026-01-15T10:00:00+00:00", "hour": 10, "temperature_c": 13.4, "condition": "partly_cloudy", "humidity": 64, "wind_speed": 59.5, "solar_irradiance": 277.4}, {"timestamp": "2026-01-15T11:00:00+00:00", "hour": 11, "temperature_c": 13.2, "condition": "partly_cloudy", "humidity": 53, "wind_speed": 50.4, "solar_irradiance": 432.4}, {"timestamp": "2026-01-15T12:00:00+00:00", "hour": 12, "temperature_c": 13.0, "condition": "partly_cloudy", "humidity": 21, "wind_speed": 70.6, "solar_irradiance": 543.0}, {"timestamp": "2026-01-15T13:00:00+00:00", "hour": 13, "temp ...
#     AIMessage(content="To determine whether it's cheaper to charge your EV at night or in the afternoon, let's look at the electricity prices for both time periods:\n\n### Electricity Prices:\n- **Night (Off-Peak Hours)**:\n  - 00:00 - 05:00: $0.09 per kWh\n  - 06:00: $0.156 per kWh (peak starts)\n\n- **Afternoon (Peak Hours)**:\n  - 12:00 - 18:00: $0.18 to $0.216 per kWh\n\n### Summary:\n- **Charging at Night**: $0.09 per kWh (off-peak)\n- **Charging in the Afternoon**: $0.18 to $0.216 per kWh (peak)\n\n### Recommendation:\n**Charge your EV at night** during the off-peak hours (00:00 - 05:00) when the rate is significantly lower at $0.09 per kWh. \n\n### Why This is Optimal:\n- Charging at night saves you approximately **50%** compared to charging during the afternoon peak hours, where rates can go up to $0.216 per kWh. \n\n### Cost Impact:\nIf you charge your EV for, say, 10 kWh:\n- **Night Cost**: 10 kWh * $0.09 = $0.90\n- **Afternoon Cost**: 10 kWh * $0.216 = $2.16\n\nBy charging at night, you save **$1.26** per 10 kWh charged. \n\n### Conclusion:\nFor cost efficiency, always opt to charge your EV at night.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 341, 'prompt_tokens': 7178, 'total_tokens': 7519, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-CxwzGNWkTUDZAJoPJw8pkyp2YOWnw', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--019bbd19-a660-74c3-92e6-744ef2f0b526-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 7178, 'output_tokens': 341, 'total_tokens': 7519, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['get_electricity_prices'],
#   'expected_response': 'comparison of charging costs',
#   'timestamp': '2026-01-14T16:22:19.808236'},
#  {'test_id': 'solar_generation_history',
#   'question': 'How much solar energy did I generate last week?',
#   'response': {'messages': [SystemMessage(content='Location: Madrid, Spain', additional_kwargs={}, response_metadata={}, id='56a2d6a0-0451-4081-bcbd-9d354b2f2827'),
#     HumanMessage(content='How much solar energy did I generate last week?', additional_kwargs={}, response_metadata={}, id='4d8c3b5d-4fa3-44c4-a9a6-cee7c1f9ae74'),
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 32, 'prompt_tokens': 1075, 'total_tokens': 1107, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-CxwzM9tAH145rdI2xC8CwvxcqGryb', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--019bbd19-bf24-7291-bb0a-d5ba1e17d6ca-0', tool_calls=[{'name': 'query_solar_generation', 'args': {'start_date': '2023-10-09', 'end_date': '2023-10-15'}, 'id': 'call_v1Dt33y9sc9leJlDTMhTw7cZ', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1075, 'output_tokens': 32, 'total_tokens': 1107, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"start_date": "2023-10-09", "end_date": "2023-10-15", "total_records": 0, "total_generation_kwh": 0, "average_daily_generation": 0.0, "records": []}', name='query_solar_generation', id='0e501e93-cf36-434e-a90b-cbf0255b7d4d', tool_call_id='call_v1Dt33y9sc9leJlDTMhTw7cZ'),
# ...
#     AIMessage(content="To minimize costs when running your washing machine in Madrid, you should consider both the electricity pricing and the availability of solar energy. Here's the optimal plan:\n\n### Best Time to Run Your Washing Machine:\n1. **Off-Peak Hours**: \n   - **Midnight to 6 AM**: The electricity rate is **$0.09 per kWh** during these hours, which is significantly lower than peak rates.\n   - **After 10 PM**: You can also run your washing machine after 10 PM when the rate remains at **$0.09 per kWh**.\n\n2. **Solar Energy Consideration**:\n   - If you have solar panels, running your washing machine during the day when solar energy is available (especially between **12 PM and 2 PM**) can further reduce costs, as you can use the energy generated by your solar system.\n\n### Recommended Schedule:\n- **Best Option**: Run your washing machine between **12 PM and 2 PM** if you have solar panels.\n- **Alternative Option**: If you don't have solar panels, run it between **12 AM and 6 AM** for the lowest electricity cost.\n\n### Why This is Optimal:\n- **Cost Efficiency**: Off-peak rates are significantly lower, saving you money.\n- **Maximizing Solar Usage**: If you have solar panels, using energy generated during the day reduces reliance on grid electricity, further lowering costs.\n\n### Estimated Savings:\n- If your washing machine uses about **1 kWh per load**, running it during off-peak hours could save you approximately **$0.09 per load** compared to peak hours. If you run multiple loads, these savings can add up quickly.\n\nBy following this schedule, you can effectively reduce your electricity costs while maintaining comfort and convenience.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 366, 'prompt_tokens': 3731, 'total_tokens': 4097, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-CxwzWOKqevJ99Jq9GyvEZ9Afdar52', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--019bbd19-e52e-7e22-9960-34d69e129aec-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 3731, 'output_tokens': 366, 'total_tokens': 4097, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['get_electricity_prices'],
#   'expected_response': 'optimal scheduling recommendation',
#   'timestamp': '2026-01-14T16:22:36.408873'},
#  {'test_id': 'hvac_solar_preheat',
#   'question': 'Should I pre-cool my house tomorrow using solar power?',
#   'response': {'messages': [SystemMessage(content='Location: Madrid, Spain', additional_kwargs={}, response_metadata={}, id='0e0dfa56-cd4f-4d2b-a683-768c3c0173cf'),
#     HumanMessage(content='Should I pre-cool my house tomorrow using solar power?', additional_kwargs={}, response_metadata={}, id='8796cc54-f530-460d-9121-126a314126cc'),
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 60, 'prompt_tokens': 1077, 'total_tokens': 1137, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-CxwzcWtav3BFRWSsNx53ctlMmrxdZ', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--019bbd19-fffa-7870-afdf-ccf5dec77aa0-0', tool_calls=[{'name': 'get_weather_forecast', 'args': {'location': 'Madrid, Spain', 'days': 1}, 'id': 'call_oL3DwDh9dJ6hX9bVnXrfYpxh', 'type': 'tool_call'}, {'name': 'get_electricity_prices', 'args': {'date': '2023-10-07'}, 'id': 'call_cFCtoRFWR3ROnu6BuyuNCy5S', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1077, 'output_tokens': 60, 'total_tokens': 1137, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"location": "Madrid, Spain", "forecast_days": 1, "source": "mock_fallback", "current": {"temperature_c": 12.4, "condition": "partly_cloudy", "humidity": 48, "wind_speed": 41.3, "solar_irradiance": 318.6}, "hourly": [{"timestamp": "2026-01-14T15:00:00+00:00", "hour": 15, "temperature_c": 12.4, "condition": "partly_cloudy", "humidity": 48, "wind_speed": 41.3, "solar_irradiance": 318.6}, {"timestamp": "2026-01-14T16:00:00+00:00", "hour": 16, "temperature_c": 11.5, "condition": "partly_cloudy", "humidity": 62, "wind_speed": 60.2, "solar_irradiance": 269.1}, {"timestamp": "2026-01-14T17:00:00+00:00", "hour": 17, "temperature_c": 10.1, "condition": "partly_cloudy", "humidity": 83, "wind_speed": 65.5, "solar_irradiance": 188.2}, {"timestamp": "2026-01-14T18:00:00+00:00", "hour": 18, "temperature_c": 9.5, "condition": "partly_cloudy", "humidity": 70, "wind_speed": 66.6, "solar_irradiance": 96.2}, {"timestamp": "2026-01-14T19:00:00+00:00", "hour": 19, "temperature_c": 7.4, "condition": "cloudy", "humidity": 51, "wind_speed": 54.5, "solar_irradiance": 48.7}, {"timestamp": "2026-01-14T20:00:00+00:00", "hour": 20, "temperature_c": 7.2, "condition": "partly_cloudy", "humidity": 46, "wind_speed": 67.7, "solar_irradiance": 0.0}, {"timestamp": "2026-01-14T21:00:00+00:00", "hour": 21, "temperature_c": 5.3, "condition": "rainy", "humidity": 29, "wind_speed": 54.8, "solar_irradiance": 0.0}, {"timestamp": "2026-01-14T22:00:00+00:00", "hour": 22, "temperature_c": 4.8, "condition": "partly_cloudy", "humidity": 60, "wind_speed": 59.8, "solar_irradiance": 0.0}, {"timestamp": "2026-01-14T23:00:00+00:00", "hour": 23, "temperature_c": 5.1, "condition": "partly_cloudy", "humidity": 59, "wind_speed": 63.1, "solar_irradiance": 0.0}, {"timestamp": "2026-01-15T00:00:00+00:00", "hour": 0, "temperature_c": 5.0, "condition": "cloudy", "humidity": 54, "wind_speed": 48.4, "solar_irradiance": 0.0}, {"timestamp": "2026-01-15T01:00:00+00:00", "hour": 1, "temperature_c": 5.2, "condition": "partly_cloudy", "humidity": 74, "wind_speed": 39.3, "solar_irradiance": 0.0}, {"timestamp": "2026-01-15T02:00:00+00:00", "hour": 2, "temperature_c": 4.8, "condition": "partly_cloudy", "humidity": 53, "wind_speed": 62.3, "solar_irradiance": 0.0}, {"timestamp": "2026-01-15T03:00:00+00:00", "hour": 3, "temperature_c": 6.2, "condition": "partly_cloudy", "humidity": 42, "wind_speed": 51.1, "solar_irradiance": 0.0}, {"timestamp": "2026-01-15T04:00:00+00:00", "hour": 4, "temperature_c": 6.2, "condition": "partly_cloudy", "humidity": 77, "wind_speed": 39.5, "solar_irradiance": 0.0}, {"timestamp": "2026-01-15T05:00:00+00:00", "hour": 5, "temperature_c": 8.0, "condition": "partly_cloudy", "humidity": 36, "wind_speed": 40.1, "solar_irradiance": 0.0}, {"timestamp": "2026-01-15T06:00:00+00:00", "hour": 6, "temperature_c": 8.8, "condition": "cloudy", "humidity": 53, "wind_speed": 39.2, "solar_irradiance": 0.0}, {"timestamp": "2026-01-15T07:00:00+00:00", "hour": 7, "temperature_c": 10.5, "condition": "partly_cloudy", "humidity": 46, "wind_speed": 34.5, "solar_irradiance": 55.0}, {"timestamp": "2026-01-15T08:00:00+00:00", "hour": 8, "temperature_c": 11.1, "condition": "sunny", "humidity": 64, "wind_speed": 65.6, "solar_irradiance": 87.5}, {"timestamp": "2026-01-15T09:00:00+00:00", "hour": 9, "temperature_c": 12.1, "condition": "partly_cloudy", "humidity": 55, "wind_speed": 43.5, "solar_irradiance": 182.8}, {"timestamp": "2026-01-15T10:00:00+00:00", "hour": 10, "temperature_c": 13.4, "condition": "partly_cloudy", "humidity": 64, "wind_speed": 59.5, "solar_irradiance": 277.4}, {"timestamp": "2026-01-15T11:00:00+00:00", "hour": 11, "temperature_c": 13.2, "condition": "partly_cloudy", "humidity": 53, "wind_speed": 50.4, "solar_irradiance": 432.4}, {"timestamp": "2026-01-15T12:00:00+00:00", "hour": 12, "temperature_c": 13.0, "condition": "partly_cloudy", "humidity": 21, "wind_speed": 70.6, "solar_irradiance": 543.0}, {"timestamp": "2026-01-15T13:00:00+00:00", "hour": 13, "temp ...
#     ToolMessage(content='{"date": "2023-10-07", "pricing_type": "time_of_use", "currency": "USD", "unit": "per_kwh", "hourly_rates": [{"hour": 0, "rate": 0.09, "period": "off_peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.09, "period": "off_peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.09, "period": "off_peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.09, "period": "off_peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.09, "period": "off_peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.09, "period": "off_peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.156, "period": "peak", "demand_charge": 0.05}, {"hour": 7, "rate": 0.156, "period": "peak", "demand_charge": 0.05}, {"hour": 8, "rate": 0.156, "period": "peak", "demand_charge": 0.05}, {"hour": 9, "rate": 0.156, "period": "peak", "demand_charge": 0.05}, {"hour": 10, "rate": 0.156, "period": "peak", "demand_charge": 0.05}, {"hour": 11, "rate": 0.156, "period": "peak", "demand_charge": 0.05}, {"hour": 12, "rate": 0.18, "period": "peak", "demand_charge": 0.05}, {"hour": 13, "rate": 0.18, "period": "peak", "demand_charge": 0.05}, {"hour": 14, "rate": 0.18, "period": "peak", "demand_charge": 0.05}, {"hour": 15, "rate": 0.18, "period": "peak", "demand_charge": 0.05}, {"hour": 16, "rate": 0.18, "period": "peak", "demand_charge": 0.05}, {"hour": 17, "rate": 0.18, "period": "peak", "demand_charge": 0.05}, {"hour": 18, "rate": 0.216, "period": "peak", "demand_charge": 0.05}, {"hour": 19, "rate": 0.216, "period": "peak", "demand_charge": 0.05}, {"hour": 20, "rate": 0.216, "period": "peak", "demand_charge": 0.05}, {"hour": 21, "rate": 0.216, "period": "peak", "demand_charge": 0.05}, {"hour": 22, "rate": 0.216, "period": "peak", "demand_charge": 0.05}, {"hour": 23, "rate": 0.09, "period": "off_peak", "demand_charge": 0.0}]}', name='get_electricity_prices', id='5ea67988-c860-48b3-9818-52856c023b31', tool_call_id='call_cFCtoRFWR3ROnu6BuyuNCy5S'),
#     AIMessage(content='### Recommendation: Pre-Cool Your House Tomorrow Using Solar Power\n\n#### Key Insights:\n1. **Weather Forecast**:\n   - Tomorrow (October 7), Madrid is expected to have partly cloudy conditions with solar irradiance peaking around midday.\n   - Solar irradiance will be highest from approximately 12 PM to 2 PM, reaching up to 639.8 W/m².\n\n2. **Electricity Pricing**:\n   - The electricity rates are lower during off-peak hours (0.09 USD/kWh) and peak during the day (up to 0.216 USD/kWh).\n   - Peak pricing occurs from 6 AM to 8 PM, with the highest rates between 6 PM and 8 PM.\n\n#### Action Steps:\n1. **Pre-Cooling Schedule**:\n   - **Start Pre-Cooling**: Begin cooling your house early in the morning (around 6 AM) when the electricity rate is lower (0.156 USD/kWh).\n   - **Maximize Solar Usage**: Increase cooling from 12 PM to 2 PM when solar power generation is at its peak. This will help reduce reliance on grid electricity during peak pricing hours.\n\n2. **Monitor Temperature**: \n   - Set your thermostat to a comfortable level (around 22-24°C) to ensure comfort while optimizing energy usage.\n\n#### Why This is Optimal:\n- **Cost Savings**: By pre-cooling during off-peak hours and utilizing solar energy during peak hours, you minimize electricity costs significantly.\n- **Comfort Maintenance**: Pre-cooling ensures that your home remains comfortable during the hotter parts of the day without incurring high electricity costs.\n\n### Estimated Impact:\n- **Cost Savings**: By using solar energy during peak hours and off-peak rates in the morning, you can save on electricity costs, especially during the peak pricing period.\n\nBy following this plan, you can effectively manage your energy usage while ensuring your home remains comfortable.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 397, 'prompt_tokens': 3741, 'total_tokens': 4138, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_29330a9688', 'id': 'chatcmpl-Cxwzef4tsITPQe8DB36UxnHzDCfBQ', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--019bbd1a-0764-7111-b5bf-dd1a9abb4e16-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 3741, 'output_tokens': 397, 'total_tokens': 4138, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['get_weather_forecast'],
#   'expected_response': 'pre-cooling recommendation based on solar forecast',
#   'timestamp': '2026-01-14T16:22:46.021843'}]

# %% [markdown]
# ## 4. Evaluate Responses

# %%
def evaluate_response(question, final_response, expected_response):
    """Evaluate a single response against expected response"""

    if not final_response or not isinstance(final_response, str):
        return 0
    keywords= ["reccomend", "should", "best", "cost", "save", "price", "off-peak"]
    score= sum(1 for k in keywords if k in final_response.lower())
    return min(score/4, 1.0)

# %%
def evaluate_tool_usage(messages, expected_tools):
    """Evaluate if the right tools were used"""
    used_tools= set()
    
    for msg in messages:
        obj= msg.model_dump()
        if obj.get("tool_call_id"):
            used_tools.add(msg.name)
    matches= sum(1 for t in expected_tools if t in used_tools)

    return matches / len(expected_tools) if expected_tools else 1.0

# %%
def generate_evaluation_report():
    total_tests= len(test_results)
    response_scores= []
    tool_scores= []

    for r in test_results:
        resp= r["response"]
        messages= resp["messages"]

        final_text= messages[-1].content if messages else ""
        response_scores.append(evaluate_response(r["question"], final_text, r["expected_response"]))
        tool_scores.append(evaluate_tool_usage(messages, r["expected_tools"]))
    
    report = {
        "total_tests": total_tests,
        "avg_response_score": round(sum(response_scores) / total_tests, 2),
        "avg_tool_usage_score": round(sum(tool_scores) / total_tests, 2),
        "strengths": "Uses tools appropriately and provides actionable recommendations",
        "weaknesses": "Mock pricing and weather limit real-world accuracy",
        "recommendations": "Integrate real APIs and improve numeric precision",
    }

    return report

print (generate_evaluation_report())
# Out:
# {'total_tests': 10, 'avg_response_score': 0.57, 'avg_tool_usage_score': 0.85, 'strengths': 'Uses tools appropriately and provides actionable recommendations', 'weaknesses': 'Mock pricing and weather limit real-world accuracy', 'recommendations': 'Integrate real APIs and improve numeric precision'}
